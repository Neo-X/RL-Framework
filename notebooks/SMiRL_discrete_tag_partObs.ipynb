# %% [markdown]
# # SMIRL on discrete tag environment, partially observed

# %%
# Go to the RL-Framework directory
if '__initialized' not in locals():
    import os
    os.chdir('../')
    __initialized = True

# %% [markdown]
# ### Train

# %%
# TODO: This is wrong
# !python3 trainModel.py --config=settings/MiniGrid/simpleRoomLatent/DQN/Tensorflow_SimpleRoom_Tag_HMM_Marginal_FullObs.json --shouldRender=false --plot=false --checkpoint_vid_rounds=5 --save_video_to_file=evalSMiRL_on_TagEnv.mp4
# Out:
# Updateing option:  verbose  =  False
# Updateing option:  save_video_to_file  =  evalSMiRL_on_TagEnv.mp4
# Updateing option:  visualize_learning  =  false
# Updateing option:  shouldRender  =  false
# Updateing option:  configFile  =  settings/MiniGrid/simpleRoomLatent/DQN/Tensorflow_SimpleRoom_Tag_HMM_Marginal_FullObs.json
# Updateing option:  checkpoint_vid_rounds  =  5
# Number of agents:  1
# Sim config file name: MiniGrid-SimpleEnemyTagEnvHMMMarginalFullObs-v0
# original exp:  None
# Not Multi task simulation
# Setting sim_id to: None
# original exp:  None
# Not Multi task simulation
# Setting sim_id to: None
# Sim worker
# <SimWorker(SimWorker-2, initial)>
# M
# Creating sim Type:  open_AI_Gym
# Sim worker
# <SimWorker(SimWorker-3, initial)>
# roboschool not installed
# Membrane/gymdrl not installed
# pybullet not installed
# multiworld not installed
# metaworld not installed
# rlsimenv not installed
# ...

# %% [markdown]
# ### Videos

# %% [markdown]
# ### Plots
